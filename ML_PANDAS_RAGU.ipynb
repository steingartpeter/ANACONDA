# %%
! pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
ownDf = pd.read_csv("/home/blaise/CODE/ANACONDA/Jupyter Notebook_files/testData01.csv")

# %%
ownDf
# Out:
#              date      hour  lines  free_hours  wrk_hours  income   expns  \
# 0      2010-01-01  00:00:00      0           0          0     0.0   11.25
# 1      2010-01-01  01:00:00      0           0          0     0.0   11.25
# 2      2010-01-01  02:00:00      0           0          0     0.0   11.25
# 3      2010-01-01  03:00:00      0           0          0     0.0   11.25
# 4      2010-01-01  04:00:00      0           0          0     0.0   11.25
# ...           ...       ...    ...         ...        ...     ...     ...
# 34994  2013-12-29  02:00:00      0           0          0     0.0   11.25
# 34995  2013-12-29  03:00:00      0           0          0     0.0   11.25
# 34996  2013-12-29  04:00:00      0           0          0     0.0   11.25
# 34997  2013-12-29  05:00:00      0           0          0     0.0   11.25
# 34998  2013-12-29  06:00:00    268          54         26    94.8  308.95
#
#        accidents weather  marketshre_chng
# ...

# %%
uberDf = pd.read_csv("uberData.csv")

# %%
uberDf.head(5)
# Out:
#             START_DATE             END_DATE  CATEGORY       START        STOP  \
# 0  2016-01-01 10:05:00  2016-01-01 21:33:00  Business     Georgia     Georgia
# 1  2016-01-02 13:05:00  2016-01-04 00:45:00     Other  California  California
# 2  2016-01-03 13:05:00  2016-01-05 00:20:00     Other    Oklahoma    Oklahoma
# 3  2016-01-03 19:05:00  2016-01-05 09:14:00    Public       Texas       Texas
# 4  2016-01-04 04:05:00  2016-01-04 12:26:00  Business  Washington  Washington
#
#    MILES          PURPOSE
# 0  11.02          Meeting
# 1   3.42          Meeting
# 2  13.00   Meal/Enetrtain
# 3   4.89   Customer visit
# 4  16.31  Errand/Supplies

# %% [markdown]
# # KEY MODULES

# %% [markdown]
# ## 1) Basic dataframe operations
# ## 2) Common data manipulation tasks
# ## 3) Loops and functions

# %% [markdown]
# DF = dataframe<br>
# rows and columns like spreadsheet<br>
# typeof(df)<br>

# %%
type(ownDf)
# Out:
# pandas.core.frame.DataFrame

# %%
ownDf.dtypes
# Out:
# date                object
# hour                object
# lines                int64
# free_hours           int64
# wrk_hours            int64
# income             float64
# expns              float64
# accidents            int64
# weather             object
# marketshre_chng    float64
# dtype: object

# %%
uberDf.dtypes
# Out:
# START_DATE     object
# END_DATE       object
# CATEGORY       object
# START          object
# STOP           object
# MILES         float64
# PURPOSE        object
# dtype: object

# %% [markdown]
# #### From this we can see, that the date+time comes in as string(object)

# %%
uberDf.head(5)
# Out:
#             START_DATE             END_DATE  CATEGORY       START        STOP  \
# 0  2016-01-01 10:05:00  2016-01-01 21:33:00  Business     Georgia     Georgia
# 1  2016-01-02 13:05:00  2016-01-04 00:45:00     Other  California  California
# 2  2016-01-03 13:05:00  2016-01-05 00:20:00     Other    Oklahoma    Oklahoma
# 3  2016-01-03 19:05:00  2016-01-05 09:14:00    Public       Texas       Texas
# 4  2016-01-04 04:05:00  2016-01-04 12:26:00  Business  Washington  Washington
#
#    MILES          PURPOSE
# 0  11.02          Meeting
# 1   3.42          Meeting
# 2  13.00   Meal/Enetrtain
# 3   4.89   Customer visit
# 4  16.31  Errand/Supplies

# %%
uberDf
# Out:
#                  START_DATE             END_DATE  CATEGORY       START  \
# 0       2016-01-01 10:05:00  2016-01-01 21:33:00  Business     Georgia
# 1       2016-01-02 13:05:00  2016-01-04 00:45:00     Other  California
# 2       2016-01-03 13:05:00  2016-01-05 00:20:00     Other    Oklahoma
# 3       2016-01-03 19:05:00  2016-01-05 09:14:00    Public       Texas
# 4       2016-01-04 04:05:00  2016-01-04 12:26:00  Business  Washington
# ...                     ...                  ...       ...         ...
# 124994  2251-08-13 13:05:00  2251-08-14 11:45:00   Medical   Tennessee
# 124995  2251-08-13 19:05:00  2251-08-14 10:02:00  Personal  California
# 124996  2251-08-14 07:05:00  2251-08-15 19:57:00     Other  California
# 124997  2251-08-14 22:05:00  2251-08-16 09:05:00     Other      Nevada
# 124998  2251-08-15 13:05:00  2251-08-16 22:25:00     Other  Tennessee1
#
#               STOP  MILES          PURPOSE
# 0          Georgia  11.02          Meeting
# ...

# %%
#for printing only the first/last x rows:
uberDf.head(10)
uberDf.shape
uberDf.tail(5)
# Out:
#                  START_DATE             END_DATE  CATEGORY       START  \
# 124994  2251-08-13 13:05:00  2251-08-14 11:45:00   Medical   Tennessee
# 124995  2251-08-13 19:05:00  2251-08-14 10:02:00  Personal  California
# 124996  2251-08-14 07:05:00  2251-08-15 19:57:00     Other  California
# 124997  2251-08-14 22:05:00  2251-08-16 09:05:00     Other      Nevada
# 124998  2251-08-15 13:05:00  2251-08-16 22:25:00     Other  Tennessee1
#
#               STOP  MILES         PURPOSE
# 124994   Tennessee   9.87  Temporary site
# 124995  California  11.63  Meal/Enetrtain
# 124996  California   5.26  Meal/Enetrtain
# 124997      Nevada   2.01  Meal/Enetrtain
# 124998  Tennessee1  15.96  Customer visit

# %% [markdown]
# ## Changeing data types

# %%
temp = pd.DataFrame({"A":["1","2","3"],"B":[11,12,13],"C":["2020-05-01","2020-06-01","2020-07-01"]})

# %%
temp.dtypes
temp
# Out:
#    A   B          C
# 0  1  11 2020-05-01
# 1  2  12 2020-06-01
# 2  3  13 2020-07-01

# %%
#convert element "C" to datetime
temp["C"] = pd.to_datetime(temp["C"])
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp
# Out:
#    A   B          C
# 0  1  11 2020-05-01
# 1  2  12 2020-06-01
# 2  3  13 2020-07-01

# %%
#convert element "A" to numbers
temp["A"] = pd.to_numeric(temp["A"])
temp.dtypes
temp
# Out:
#    A   B          C
# 0  1  11 2020-05-01
# 1  2  12 2020-06-01
# 2  3  13 2020-07-01

# %%
#avoid errors to stop conversion in problematic data frames
pd.to_datetime(['2020-aug-17','abc'],errors="coerce")
# Out:
# DatetimeIndex(['2020-08-17', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
# conversion with .astype function
temp["A"] = temp["A"].astype(str)
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %% [markdown]
# #### A pd.to_datetime(dateString, format="%Y-%M-%D %H:%M:%S") alakkal aható meg az aktuális formátum

# %% [markdown]
# ## DATA SUMMARIZATION METHODS

# %% [markdown]
# ### DESCRIBE

# %%
uberDf.describe()
# Out:
#                MILES
# count  124999.000000
# mean       33.578323
# std        49.093106
# min         1.000000
# 25%         7.300000
# 50%        13.450000
# 75%        19.540000
# max       199.990000

# %%
uberDf.describe(include="all")
# Out:
#                  START_DATE             END_DATE  CATEGORY       START  \
# count                124999               124999    124999      124999
# unique               124999               124952         5          29
# top     2066-11-23 19:05:00  2215-07-21 14:06:00  Business  California
# freq                      1                    2     25123       19738
# mean                    NaN                  NaN       NaN         NaN
# std                     NaN                  NaN       NaN         NaN
# min                     NaN                  NaN       NaN         NaN
# 25%                     NaN                  NaN       NaN         NaN
# 50%                     NaN                  NaN       NaN         NaN
# 75%                     NaN                  NaN       NaN         NaN
# max                     NaN                  NaN       NaN         NaN
#
#               STOP          MILES         PURPOSE
# count       124999  124999.000000          124999
# ...

# %% [markdown]
# ### Info

# %%
uberDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124999 entries, 0 to 124998
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   START_DATE  124999 non-null  object
#  1   END_DATE    124999 non-null  object
#  2   CATEGORY    124999 non-null  object
#  3   START       124999 non-null  object
#  4   STOP        124999 non-null  object
#  5   MILES       124999 non-null  float64
#  6   PURPOSE     124999 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 6.7+ MB

# %% [markdown]
# ### value_counts

# %%
# the way you can count the unique values:
uberDf['STOP'].value_counts()
# Out:
# California        19822
# Texas             17695
# Colorado           7549
# Arizona            7495
# North Carolina     5063
# Oklahoma           5055
# Washington         4927
# Florida            4874
# Nevada             2582
# Michigan           2557
# Ohio               2538
# Virginia           2535
# Indiana            2525
# Nebraska           2525
# Kentucky2          2523
# Massachusetts      2519
# Georgia            2512
# Illinois           2509
# Minnesota          2508
# Oregon             2507
# Tennessee1         2495
#  Florida           2483
# Maryland           2482
# New York           2481
# Tennessee          2462
# Louisiana          2462
# Pennsylvania       2457
# Wisconsin          2439
# Missouri           2418
# Name: STOP, dtype: int64

# %% [markdown]
# # COMMON DATA MANIPULATION TASKS

# %% [markdown]
# #### 5 verbs of data manipulation

# %% [markdown]
# <ol>
#     <li>Selectin/Indexing</li>
#     <li>Filtering</li>
#     <li>Sorting</li>
#     <li>Mutating/Conditionally add columns</li>
#     <li>Groupby/Summarize</li>
# </ol>

# %% [markdown]
# ### SELECTING/INDEXING

# %% [markdown]
# ##### iloc

# %%
#iloc is deprecated, and will be removed, loc will be used instead of it.
uberDf.iloc[0:4,[0,3]]
# Out:
#             START_DATE       START
# 0  2016-01-01 10:05:00     Georgia
# 1  2016-01-02 13:05:00  California
# 2  2016-01-03 13:05:00    Oklahoma
# 3  2016-01-03 19:05:00       Texas

# %%
#all rows, but 1,3,5 columns
uberDf.iloc[:,[1,3,5]]
# Out:
#                    END_DATE       START  MILES
# 0       2016-01-01 21:33:00     Georgia  11.02
# 1       2016-01-04 00:45:00  California   3.42
# 2       2016-01-05 00:20:00    Oklahoma  13.00
# 3       2016-01-05 09:14:00       Texas   4.89
# 4       2016-01-04 12:26:00  Washington  16.31
# ...                     ...         ...    ...
# 124994  2251-08-14 11:45:00   Tennessee   9.87
# 124995  2251-08-14 10:02:00  California  11.63
# 124996  2251-08-15 19:57:00  California   5.26
# 124997  2251-08-16 09:05:00      Nevada   2.01
# 124998  2251-08-16 22:25:00  Tennessee1  15.96
#
# [124999 rows x 3 columns]

# %%
# all the ows and columns except the last one
uberDf.iloc[:,: -1]
# Out:
#                  START_DATE             END_DATE  CATEGORY       START  \
# 0       2016-01-01 10:05:00  2016-01-01 21:33:00  Business     Georgia
# 1       2016-01-02 13:05:00  2016-01-04 00:45:00     Other  California
# 2       2016-01-03 13:05:00  2016-01-05 00:20:00     Other    Oklahoma
# 3       2016-01-03 19:05:00  2016-01-05 09:14:00    Public       Texas
# 4       2016-01-04 04:05:00  2016-01-04 12:26:00  Business  Washington
# ...                     ...                  ...       ...         ...
# 124994  2251-08-13 13:05:00  2251-08-14 11:45:00   Medical   Tennessee
# 124995  2251-08-13 19:05:00  2251-08-14 10:02:00  Personal  California
# 124996  2251-08-14 07:05:00  2251-08-15 19:57:00     Other  California
# 124997  2251-08-14 22:05:00  2251-08-16 09:05:00     Other      Nevada
# 124998  2251-08-15 13:05:00  2251-08-16 22:25:00     Other  Tennessee1
#
#               STOP  MILES
# 0          Georgia  11.02
# 1       California   3.42
# 2         Oklahoma  13.00
# ...

# %% [markdown]
# ##### loc = label based indexing

# %%
uberDf.loc[1500:1505,["CATEGORY","START","STOP"]]
# Out:
#       CATEGORY           START            STOP
# 1500     Other           Texas           Texas
# 1501    Public  North Carolina  North Carolina
# 1502  Business          Nevada            Ohio
# 1503     Other        Virginia        Virginia
# 1504    Public      Washington      Washington
# 1505   Medical      California      California

# %%
uberDf.loc[0:6]
# Out:
#             START_DATE             END_DATE  CATEGORY           START  \
# 0  2016-01-01 10:05:00  2016-01-01 21:33:00  Business         Georgia
# 1  2016-01-02 13:05:00  2016-01-04 00:45:00     Other      California
# 2  2016-01-03 13:05:00  2016-01-05 00:20:00     Other        Oklahoma
# 3  2016-01-03 19:05:00  2016-01-05 09:14:00    Public           Texas
# 4  2016-01-04 04:05:00  2016-01-04 12:26:00  Business      Washington
# 5  2016-01-04 22:05:00  2016-01-06 14:50:00     Other  North Carolina
# 6  2016-01-05 13:05:00  2016-01-05 16:14:00    Public        Virginia
#
#          STOP  MILES          PURPOSE
# 0     Georgia  11.02          Meeting
# 1  California   3.42          Meeting
# 2    Oklahoma  13.00   Meal/Enetrtain
# 3       Texas   4.89   Customer visit
# 4  Washington  16.31  Errand/Supplies
# 5    Missouri  46.33   Meal/Enetrtain
# 6    Virginia  18.26   Temporary site

# %%
uberDf.loc[10:16,['START_DATE','CATEGORY','MILES']]
# Out:
#              START_DATE  CATEGORY   MILES
# 10  2016-01-08 07:05:00    Public  113.76
# 11  2016-01-09 04:05:00  Business   18.62
# 12  2016-01-10 04:05:00  Personal  129.72
# 13  2016-01-10 16:05:00    Public    7.65
# 14  2016-01-11 16:05:00   Medical   17.97
# 15  2016-01-12 19:05:00   Medical   16.20
# 16  2016-01-13 04:05:00  Business   18.30

# %% [markdown]
# ### Filtering

# %%
uberDf['MILES'] > 10
# Out:
# 0          True
# 1         False
# 2          True
# 3         False
# 4          True
#           ...
# 124994    False
# 124995     True
# 124996    False
# 124997    False
# 124998     True
# Name: MILES, Length: 124999, dtype: bool

# %%
uDf2 = uberDf.loc[uberDf['MILES'] > 100]
uDf2.head(10)
# Out:
#               START_DATE             END_DATE  CATEGORY       START  \
# 10   2016-01-08 07:05:00  2016-01-08 23:48:00    Public       Texas
# 12   2016-01-10 04:05:00  2016-01-10 19:58:00  Personal    Michigan
# 81   2016-03-06 04:05:00  2016-03-07 02:26:00   Medical     Florida
# 100  2016-03-17 13:05:00  2016-03-19 06:13:00     Other    Illinois
# 109  2016-03-22 13:05:00  2016-03-23 15:36:00   Medical    Nebraska
# 116  2016-03-26 10:05:00  2016-03-26 15:09:00   Medical  California
# 122  2016-03-31 04:05:00  2016-03-31 22:39:00   Medical    Virginia
# 130  2016-04-05 19:05:00  2016-04-05 20:30:00  Personal  California
# 132  2016-04-06 13:05:00  2016-04-06 16:32:00  Personal    Missouri
# 153  2016-04-21 16:05:00  2016-04-22 21:57:00   Medical    New York
#
#           STOP   MILES          PURPOSE
# 10     Florida  113.76  Errand/Supplies
# 12     Arizona  129.72          Meeting
# 81    Oklahoma  106.31  Errand/Supplies
# 100      Texas  105.98   Temporary site
# ...

# %%
uDf3 = uberDf.loc[uberDf['START'] == 'Texas']
uDf3.head()
# Out:
#              START_DATE             END_DATE  CATEGORY  START     STOP  \
# 3   2016-01-03 19:05:00  2016-01-05 09:14:00    Public  Texas    Texas
# 8   2016-01-06 19:05:00  2016-01-08 12:09:00    Public  Texas    Texas
# 10  2016-01-08 07:05:00  2016-01-08 23:48:00    Public  Texas  Florida
# 23  2016-01-18 13:05:00  2016-01-20 05:29:00  Personal  Texas    Texas
# 26  2016-01-21 07:05:00  2016-01-22 06:44:00  Personal  Texas    Texas
#
#      MILES          PURPOSE
# 3     4.89   Customer visit
# 8    10.63          Meeting
# 10  113.76  Errand/Supplies
# 23    4.27   Customer visit
# 26    3.03   Meal/Enetrtain

# %%
uDf3.shape
# Out:
# (17519, 7)

# %%
uDf3 = uberDf.loc[(uberDf['START'] == 'Texas') & (uberDf['STOP'] != 'Texas') & (uberDf['MILES'] < 100)]
uDf3.head()
# Out:
#               START_DATE             END_DATE  CATEGORY  START        STOP  \
# 119  2016-03-28 22:05:00  2016-03-29 21:23:00  Business  Texas   Wisconsin
# 223  2016-06-13 01:05:00  2016-06-14 17:06:00  Business  Texas     Florida
# 246  2016-06-29 10:05:00  2016-07-01 00:52:00    Public  Texas    Missouri
# 275  2016-07-19 22:05:00  2016-07-20 03:21:00     Other  Texas  Washington
# 581  2017-02-04 01:05:00  2017-02-05 02:53:00   Medical  Texas    New York
#
#      MILES          PURPOSE
# 119  19.74   Meal/Enetrtain
# 223  92.76          Meeting
# 246  30.89  Errand/Supplies
# 275  19.73  Errand/Supplies
# 581  35.33   Customer visit

# %%
uDf3.shape
# Out:
# (1842, 7)

# %%
uDf3 = uberDf.loc[(uberDf['START'].isin(['Texas','New York'])) & (uberDf['MILES'] < 100)]
uDf3.head()
# Out:
#              START_DATE             END_DATE  CATEGORY     START      STOP  \
# 3   2016-01-03 19:05:00  2016-01-05 09:14:00    Public     Texas     Texas
# 8   2016-01-06 19:05:00  2016-01-08 12:09:00    Public     Texas     Texas
# 23  2016-01-18 13:05:00  2016-01-20 05:29:00  Personal     Texas     Texas
# 26  2016-01-21 07:05:00  2016-01-22 06:44:00  Personal     Texas     Texas
# 35  2016-01-28 16:05:00  2016-01-28 22:24:00    Public  New York  New York
#
#     MILES          PURPOSE
# 3    4.89   Customer visit
# 8   10.63          Meeting
# 23   4.27   Customer visit
# 26   3.03   Meal/Enetrtain
# 35   8.84  Errand/Supplies

# %%
uDf3.head(10)
# Out:
#              START_DATE             END_DATE  CATEGORY     START      STOP  \
# 3   2016-01-03 19:05:00  2016-01-05 09:14:00    Public     Texas     Texas
# 8   2016-01-06 19:05:00  2016-01-08 12:09:00    Public     Texas     Texas
# 23  2016-01-18 13:05:00  2016-01-20 05:29:00  Personal     Texas     Texas
# 26  2016-01-21 07:05:00  2016-01-22 06:44:00  Personal     Texas     Texas
# 35  2016-01-28 16:05:00  2016-01-28 22:24:00    Public  New York  New York
# 41  2016-02-03 04:05:00  2016-02-03 12:46:00  Business     Texas     Texas
# 43  2016-02-04 22:05:00  2016-02-06 09:56:00  Business     Texas     Texas
# 45  2016-02-06 22:05:00  2016-02-07 07:23:00    Public     Texas     Texas
# 61  2016-02-19 19:05:00  2016-02-21 08:03:00   Medical     Texas     Texas
# 66  2016-02-23 07:05:00  2016-02-23 17:24:00  Personal     Texas     Texas
#
#     MILES          PURPOSE
# 3    4.89   Customer visit
# 8   10.63          Meeting
# 23   4.27   Customer visit
# 26   3.03   Meal/Enetrtain
# ...

# %%
uDf3.reset_index()
# Out:
#         index           START_DATE             END_DATE  CATEGORY     START  \
# 0           3  2016-01-03 19:05:00  2016-01-05 09:14:00    Public     Texas
# 1           8  2016-01-06 19:05:00  2016-01-08 12:09:00    Public     Texas
# 2          23  2016-01-18 13:05:00  2016-01-20 05:29:00  Personal     Texas
# 3          26  2016-01-21 07:05:00  2016-01-22 06:44:00  Personal     Texas
# 4          35  2016-01-28 16:05:00  2016-01-28 22:24:00    Public  New York
# ...       ...                  ...                  ...       ...       ...
# 17717  124932  2251-06-29 13:05:00  2251-06-30 08:47:00  Personal     Texas
# 17718  124941  2251-07-06 16:05:00  2251-07-06 18:41:00  Personal     Texas
# 17719  124957  2251-07-18 13:05:00  2251-07-19 13:32:00     Other     Texas
# 17720  124964  2251-07-23 13:05:00  2251-07-24 23:05:00  Business     Texas
# 17721  124981  2251-08-04 19:05:00  2251-08-06 11:12:00     Other     Texas
#
#            STOP  MILES          PURPOSE
# ...

# %%
uDf3.reset_index(inplace=True,drop=True)
uDf3.head(10)
# Out:
#    level_0  index           START_DATE             END_DATE  CATEGORY  \
# 0        0      3  2016-01-03 19:05:00  2016-01-05 09:14:00    Public
# 1        1      8  2016-01-06 19:05:00  2016-01-08 12:09:00    Public
# 2        2     23  2016-01-18 13:05:00  2016-01-20 05:29:00  Personal
# 3        3     26  2016-01-21 07:05:00  2016-01-22 06:44:00  Personal
# 4        4     35  2016-01-28 16:05:00  2016-01-28 22:24:00    Public
# 5        5     41  2016-02-03 04:05:00  2016-02-03 12:46:00  Business
# 6        6     43  2016-02-04 22:05:00  2016-02-06 09:56:00  Business
# 7        7     45  2016-02-06 22:05:00  2016-02-07 07:23:00    Public
# 8        8     61  2016-02-19 19:05:00  2016-02-21 08:03:00   Medical
# 9        9     66  2016-02-23 07:05:00  2016-02-23 17:24:00  Personal
#
#       START      STOP  MILES          PURPOSE
# 0     Texas     Texas   4.89   Customer visit
# 1     Texas     Texas  10.63          Meeting
# 2     Texas     Texas   4.27   Customer visit
# ...

# %%
uDf3.drop(['index','level_0'],axis=1)
# Out:
#                 START_DATE             END_DATE  CATEGORY     START      STOP  \
# 0      2016-01-03 19:05:00  2016-01-05 09:14:00    Public     Texas     Texas
# 1      2016-01-06 19:05:00  2016-01-08 12:09:00    Public     Texas     Texas
# 2      2016-01-18 13:05:00  2016-01-20 05:29:00  Personal     Texas     Texas
# 3      2016-01-21 07:05:00  2016-01-22 06:44:00  Personal     Texas     Texas
# 4      2016-01-28 16:05:00  2016-01-28 22:24:00    Public  New York  New York
# ...                    ...                  ...       ...       ...       ...
# 17717  2251-06-29 13:05:00  2251-06-30 08:47:00  Personal     Texas     Texas
# 17718  2251-07-06 16:05:00  2251-07-06 18:41:00  Personal     Texas     Texas
# 17719  2251-07-18 13:05:00  2251-07-19 13:32:00     Other     Texas     Texas
# 17720  2251-07-23 13:05:00  2251-07-24 23:05:00  Business     Texas     Texas
# 17721  2251-08-04 19:05:00  2251-08-06 11:12:00     Other     Texas     Texas
#
#        MILES          PURPOSE
# ...

# %% [markdown]
# ### Sorting

# %%
# sorting the uDf3 list by MILES column in descending order Limit 10 
uDf3.sort_values(by=['MILES'],ascending=False).head(10)
# Out:
#        level_0   index           START_DATE             END_DATE  CATEGORY  \
# 15649    15649  110570  2224-06-20 04:05:00  2224-06-20 20:57:00   Medical
# 5927      5927   42118  2095-07-06 16:05:00  2095-07-06 21:02:00   Medical
# 16071    16071  113443  2229-11-10 19:05:00  2229-11-11 02:53:00  Business
# 558        558    3989  2023-07-07 07:05:00  2023-07-08 12:10:00     Other
# 12550    12550   88612  2182-12-31 19:05:00  2183-01-01 21:50:00    Public
# 8264      8264   58493  2126-03-16 07:05:00  2126-03-17 01:08:00   Medical
# 8630      8630   61072  2131-02-05 13:05:00  2131-02-06 21:01:00   Medical
# 8462      8462   59765  2128-08-18 13:05:00  2128-08-19 11:16:00  Business
# 7143      7143   50732  2111-08-10 13:05:00  2111-08-11 19:33:00    Public
# 7989      7989   56601  2122-08-20 22:05:00  2122-08-21 04:18:00    Public
#
#           START           STOP  MILES          PURPOSE
# 15649     Texas        Florida  99.92          Meeting
# ...

# %%
# sorting the uDf3 list by MILES, and PURPOSE, column in descending+ascending order Limit 10 
uDf3.sort_values(by=['MILES','PURPOSE'],ascending=[False,True]).head(10)
# Out:
#        level_0   index           START_DATE             END_DATE  CATEGORY  \
# 15649    15649  110570  2224-06-20 04:05:00  2224-06-20 20:57:00   Medical
# 5927      5927   42118  2095-07-06 16:05:00  2095-07-06 21:02:00   Medical
# 558        558    3989  2023-07-07 07:05:00  2023-07-08 12:10:00     Other
# 16071    16071  113443  2229-11-10 19:05:00  2229-11-11 02:53:00  Business
# 12550    12550   88612  2182-12-31 19:05:00  2183-01-01 21:50:00    Public
# 8264      8264   58493  2126-03-16 07:05:00  2126-03-17 01:08:00   Medical
# 8462      8462   59765  2128-08-18 13:05:00  2128-08-19 11:16:00  Business
# 8630      8630   61072  2131-02-05 13:05:00  2131-02-06 21:01:00   Medical
# 7143      7143   50732  2111-08-10 13:05:00  2111-08-11 19:33:00    Public
# 7989      7989   56601  2122-08-20 22:05:00  2122-08-21 04:18:00    Public
#
#           START           STOP  MILES          PURPOSE
# 15649     Texas        Florida  99.92          Meeting
# ...

# %%
# sorting the uDf3 list by STOP, and MILES, column in descending+ascending order Limit 10 
uDf3.sort_values(by=['STOP','MILES'],ascending=[True,False]).head(15)
# Out:
#        level_0   index           START_DATE             END_DATE  CATEGORY  \
# 1925      1925   13932  2042-03-29 19:05:00  2042-03-30 06:56:00   Medical
# 3436      3436   24228  2061-08-29 19:05:00  2061-08-30 00:24:00   Medical
# 14726    14726  104005  2212-01-18 13:05:00  2212-01-19 01:33:00   Medical
# 2511      2511   17998  2049-11-16 07:05:00  2049-11-17 03:09:00     Other
# 6288      6288   44617  2100-03-04 07:05:00  2100-03-04 22:21:00  Personal
# 3095      3095   21920  2057-04-13 13:05:00  2057-04-14 09:26:00   Medical
# 8762      8762   62052  2132-11-12 01:05:00  2132-11-12 07:09:00  Personal
# 3328      3328   23540  2060-05-10 10:05:00  2060-05-11 15:07:00  Personal
# 17714    17714  124898  2251-06-05 10:05:00  2251-06-06 10:42:00  Personal
# 17607    17607  124200  2250-02-14 07:05:00  2250-02-15 18:01:00  Business
# 8668      8668   61385  2131-09-09 22:05:00  2131-09-10 18:56:00  Business
# ...

# %% [markdown]
# ### Conditionally adding columns

# %%
uDf3['miles_cat']=np.where(uDf3['MILES'] > 90,"LONG TRIP","FIND_TRIP_CATEG")
# Out:
# <ipython-input-56-5b21a4e51289>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uDf3['miles_cat']=np.where(uDf3['MILES'] > 90,"LONG TRIP","FIND_TRIP_CATEG")

# %%
uberDf['miles_cat']= np.where(uberDf['MILES'] > 100,"LONG_TRIP","FIND_TRIP_CATEG")

# %%
uberDf.head(20)
# Out:
#              START_DATE             END_DATE  CATEGORY           START  \
# 0   2016-01-01 10:05:00  2016-01-01 21:33:00  Business         Georgia
# 1   2016-01-02 13:05:00  2016-01-04 00:45:00     Other      California
# 2   2016-01-03 13:05:00  2016-01-05 00:20:00     Other        Oklahoma
# 3   2016-01-03 19:05:00  2016-01-05 09:14:00    Public           Texas
# 4   2016-01-04 04:05:00  2016-01-04 12:26:00  Business      Washington
# 5   2016-01-04 22:05:00  2016-01-06 14:50:00     Other  North Carolina
# 6   2016-01-05 13:05:00  2016-01-05 16:14:00    Public        Virginia
# 7   2016-01-06 10:05:00  2016-01-06 18:51:00     Other      California
# 8   2016-01-06 19:05:00  2016-01-08 12:09:00    Public           Texas
# 9   2016-01-07 10:05:00  2016-01-08 20:16:00  Business    Pennsylvania
# 10  2016-01-08 07:05:00  2016-01-08 23:48:00    Public           Texas
# 11  2016-01-09 04:05:00  2016-01-10 02:37:00  Business            Ohio
# ...

# %%
uberDf['miles_cat']= np.where(uberDf['MILES'] > 100,"LONG_TRIP","FIND_TRIP_CATEG")
#uberDf['miles_cat']= np.where((uberDf['MILES'] > 1) & (uberDf['MILES'] < 50),"SHORT_TRIP","FIND_TRIP_CATEG")
uberDf.head(20)
# Out:
#              START_DATE             END_DATE  CATEGORY           START  \
# 0   2016-01-01 10:05:00  2016-01-01 21:33:00  Business         Georgia
# 1   2016-01-02 13:05:00  2016-01-04 00:45:00     Other      California
# 2   2016-01-03 13:05:00  2016-01-05 00:20:00     Other        Oklahoma
# 3   2016-01-03 19:05:00  2016-01-05 09:14:00    Public           Texas
# 4   2016-01-04 04:05:00  2016-01-04 12:26:00  Business      Washington
# 5   2016-01-04 22:05:00  2016-01-06 14:50:00     Other  North Carolina
# 6   2016-01-05 13:05:00  2016-01-05 16:14:00    Public        Virginia
# 7   2016-01-06 10:05:00  2016-01-06 18:51:00     Other      California
# 8   2016-01-06 19:05:00  2016-01-08 12:09:00    Public           Texas
# 9   2016-01-07 10:05:00  2016-01-08 20:16:00  Business    Pennsylvania
# 10  2016-01-08 07:05:00  2016-01-08 23:48:00    Public           Texas
# 11  2016-01-09 04:05:00  2016-01-10 02:37:00  Business            Ohio
# ...

# %%
uberDf['miles_cat']=np.where(uberDf['MILES'] > 90,"LONG TRIP","FIND_TRIP_CATEG")
# uberDf = np.where((uberDf['MILES'] > 1) & (uberDf['MILES'] < 50) & (uberDf['miles_cat'] == "FIND_TRIP_CATEG"),"SHORT_TRIP","FIND_TRIP_CATEG")
uberDf.head(20)
# Out:
#              START_DATE             END_DATE  CATEGORY           START  \
# 0   2016-01-01 10:05:00  2016-01-01 21:33:00  Business         Georgia
# 1   2016-01-02 13:05:00  2016-01-04 00:45:00     Other      California
# 2   2016-01-03 13:05:00  2016-01-05 00:20:00     Other        Oklahoma
# 3   2016-01-03 19:05:00  2016-01-05 09:14:00    Public           Texas
# 4   2016-01-04 04:05:00  2016-01-04 12:26:00  Business      Washington
# 5   2016-01-04 22:05:00  2016-01-06 14:50:00     Other  North Carolina
# 6   2016-01-05 13:05:00  2016-01-05 16:14:00    Public        Virginia
# 7   2016-01-06 10:05:00  2016-01-06 18:51:00     Other      California
# 8   2016-01-06 19:05:00  2016-01-08 12:09:00    Public           Texas
# 9   2016-01-07 10:05:00  2016-01-08 20:16:00  Business    Pennsylvania
# 10  2016-01-08 07:05:00  2016-01-08 23:48:00    Public           Texas
# 11  2016-01-09 04:05:00  2016-01-10 02:37:00  Business            Ohio
# ...

# %%
uberDf
# Out:
#                  START_DATE             END_DATE  CATEGORY       START  \
# 0       2016-01-01 10:05:00  2016-01-01 21:33:00  Business     Georgia
# 1       2016-01-02 13:05:00  2016-01-04 00:45:00     Other  California
# 2       2016-01-03 13:05:00  2016-01-05 00:20:00     Other    Oklahoma
# 3       2016-01-03 19:05:00  2016-01-05 09:14:00    Public       Texas
# 4       2016-01-04 04:05:00  2016-01-04 12:26:00  Business  Washington
# ...                     ...                  ...       ...         ...
# 124994  2251-08-13 13:05:00  2251-08-14 11:45:00   Medical   Tennessee
# 124995  2251-08-13 19:05:00  2251-08-14 10:02:00  Personal  California
# 124996  2251-08-14 07:05:00  2251-08-15 19:57:00     Other  California
# 124997  2251-08-14 22:05:00  2251-08-16 09:05:00     Other      Nevada
# 124998  2251-08-15 13:05:00  2251-08-16 22:25:00     Other  Tennessee1
#
#               STOP  MILES          PURPOSE        miles_cat
# ...

# %% [markdown]
# ## GROUPING

# %% [markdown]
# ## APPLY

# %% [markdown]
# #### Grouping = Split - Apply - Combine

# %%
uberDf.groupby('START')['MILES'].agg('mean')
print("====================================================")
uberDf.groupby('START')['MILES'].mean()
# Out:
# ...
# START
# Arizona           34.653073
# California        31.362523
# Colorado          34.879509
# Florida           35.478736
# Georgia           34.286109
# Illinois          35.554487
# Indiana           33.618272
# Kentucky2         34.475520
# Louisiana         34.992589
# Maryland          34.297392
# Massachusetts     34.388997
# Michigan          35.564065
# Minnesota         35.769178
# Missouri          37.388350
# Nebraska          34.964124
# Nevada            33.670054
# New York          35.622663
# North Carolina    33.364812
# Ohio              34.963128
# Oklahoma          34.568226
# Oregon            36.220597
# Pennsylvania      33.982430
# Tennessee         32.447824
# Tennessee1        35.163028
# Texas             30.573416
# Virginia          33.692160
# Washington        33.201533
# Wisconsin         36.209885
#  Florida          34.615152
# Name: MILES, dtype: float64

# %%
data010 = uberDf.groupby(['START','STOP']).agg(['mean','min','max']).head(20)

# %%
data010.columns
# Out:
# MultiIndex([('MILES', 'mean'),
#             ('MILES',  'min'),
#             ('MILES',  'max')],
#            )

# %%
#uberDf.dtypes
#uberDf['START_DATE'] = pd.to_datetime(uberDf['START_DATE'])
#uberDf['END_DATE'] = pd.to_datetime(uberDf['END_DATE'])
#uberDf.groupby(['START'])['START_DATE'].agg(['min','max','mean'])
# =======================================================================================================
# get the earliest, and most recent trip date, and the average distance, in miles for each
# starting city: =>
# The main point is, that, for this we need to add a dictionay as an argment for the "agg" function.
# In this dictionary there is the key + value pairs, as:
# COLUMN_NAME : [array, of the functionames pplied to that column]
# =======================================================================================================
data_002 = uberDf.groupby(['START']).agg({'START_DATE':['min','max'],'MILES':['mean']})
#uberDf.tail()
data_002.head(10)
# Out:
#                     START_DATE                          MILES
#                            min                 max       mean
# START
# Arizona    2016-01-13 04:05:00 2251-07-05 16:05:00  34.653073
# California 2016-01-02 13:05:00 2251-08-14 07:05:00  31.362523
# Colorado   2016-01-20 10:05:00 2251-08-09 22:05:00  34.879509
# Florida    2016-02-24 19:05:00 2251-08-09 04:05:00  35.478736
# Georgia    2016-01-01 10:05:00 2251-06-18 10:05:00  34.286109
# Illinois   2016-02-01 01:05:00 2251-07-31 04:05:00  35.554487
# Indiana    2016-02-18 19:05:00 2251-07-25 01:05:00  33.618272
# Kentucky2  2016-02-12 01:05:00 2251-08-08 07:05:00  34.475520
# Louisiana  2016-01-25 07:05:00 2251-07-13 10:05:00  34.992589
# Maryland   2016-03-09 13:05:00 2251-07-29 07:05:00  34.297392

# %%
# To be sure, add an index
data_002.reset_index(inplace=True)

# %%
data_002.head(5)
# Out:
#    Start city       Earliest trip           Last trip  Avrg.Distance
# 0     Arizona 2016-01-13 04:05:00 2251-07-05 16:05:00      34.653073
# 1  California 2016-01-02 13:05:00 2251-08-14 07:05:00      31.362523
# 2    Colorado 2016-01-20 10:05:00 2251-08-09 22:05:00      34.879509
# 3     Florida 2016-02-24 19:05:00 2251-08-09 04:05:00      35.478736
# 4     Georgia 2016-01-01 10:05:00 2251-06-18 10:05:00      34.286109

# %%
# Change the column names or someting with meaning!
data_002.columns = ['Start city','Earliest trip','Last trip','Avrg.Distance']
