# %% [markdown]
# # Matplotlib basic plots
# (by Kieth Galli - youtube[https://www.youtube.com/watch?v=0P7QnIQDBJY])

# %%
#import neccessary libs:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the gas data 
gd = pd.read_csv('DATA/gas_prices.csv')

# %%
gd.head(5)
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
# A simple line plot, just assign something to x, and y and => done
plt.plot(gd.Year,gd.Japan)
# Lets add 2 countries, to compare
plt.plot(gd.Year,gd['USA'])
# Or three
plt.plot(gd.Year,gd['Germany'])

# %%
# Now lets resize the plot
plt.figure(figsize=(9,6))
# Lets say it is too ugly, and pimp it up a bit
plt.plot(gd.Year,gd['Japan'],'bx-')
plt.plot(gd.Year,gd['USA'],'r.-')
plt.plot(gd.Year,gd['Germany'],'g^-')
# Add some lables/ticks
plt.xticks(gd.Year,rotation=35)
plt.xlabel('YEAR')
plt.ylabel('Gall./$')

# As a first step add a title
plt.title("GAS Prices in US $")
# Now add a legend a well
plt.legend(['JPN','USA','GER'])

# %%
print(gd.columns[1:])
# Out:
# Index(['Australia', 'Canada', 'France', 'Germany', 'Italy', 'Japan', 'Mexico',
#        'South Korea', 'UK', 'USA'],
#       dtype='object')
